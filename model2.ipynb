# %%
from typing import TypedDict,Annotated,List,Literal
from langchain_core.messages import BaseMessage,HumanMessage,AIMessage,SystemMessage
from langchain_core.tools import tool
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.graph import StateGraph,END,MessagesState
from langgraph.prebuilt import create_react_agent,ToolNode
from langgraph.checkpoint.memory import MemorySaver
import random
from datetime import datetime
from langchain_core.prompts import ChatPromptTemplate

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
llm=init_chat_model("groq:llama-3.1-8b-instant")
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001C2C92C3250>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001C2C92C3C50>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
class SuperVisorState(MessagesState):
    """State for the supervisor multi - agent systems"""
    current_agent:str=""
    task_assignments:dict[str,List[str]]={}#track what each agent should do
    agent_outputs:dict[str,any]={}#store outputs from each agents
    workflow_stage:str ="initial"#track workflow progress
    iteration_count:int =0 
    max_iteration:int = 10
    final_output:str = ""

# %%
class SuperVisorState(MessagesState):
    """State for the multi-agent system"""
    next_agent:str =""
    research_data:str=""
    analysis:str=""
    final_report:str=""
    task_complete:bool=False
    current_task:str=""

# %%
def create_supervisor_agent():
    """creates the supervisor decision chain"""
    supervisor_prompt= ChatPromptTemplate.from_messages([
        ("system","""you are a supervisr managing a team of agentS:
         1.Researcher - Gathers information and data
         2.Analyst - Analyzes data and provide insights         
         3.Writer - Creates reports and summaries
         based on current state and conversation , decide which worker should work next
         if the task is complete,respond with 'Done'
         Curret state:
         -Has research data:{has_research}
         -Has analysis:{has_analysis}
         -Has report:{has_report}
         Respond with ONLY the agent name(researcher/analyst/writer) or 'DONE'
         """),
                 ("human","{task}")
            ])
    return supervisor_prompt| llm

# %%
def supervisor_agent(state:SuperVisorState)->dict:
    """Supervisor decides next agent using groq llm"""
    messages=state['messages']
    task=messages[-1].content if messages else "no task"
    has_research= bool(state.get("research_data",""))
    has_analysis=bool(state.get("analysis",""))
    has_report=bool(state.get("final_data",""))
  #get LLM reports
    chain=create_supervisor_agent()
    decision = chain.invoke({
    "task": task,
   "has_research":has_research,
   "has_analysis":has_analysis,
   "has_report":has_report
   })
#Parse condition
    decision_text=decision.content.strip().lower()
    print(decision_text)
# Determine next agent
    if "done" in decision_text or has_report:
        next_agent="end"
        supervisor_msg=" Supervisor : All tasks complete! Great work team"
    elif "researcher" in decision_text or not has_research:
        next_agent="researcher"
        supervisor_msg="Supervisor: let's start with research. Assigning to researcher..."
    elif "analyst" in decision_text or (has_research and not  has_analysis) :
        next_agent="analyst"
        supervisor_msg="Supervisor: research done. Time for analysis. Assigning to analyst..."   
    
    elif "writer" in decision_text or (has_analysis and not  has_report) :
        next_agent="writer"
        supervisor_msg="Supervisor: Analysis complete. Let's create the report. Assigning to Writer..."
    else :
        next_agent="end"
        supervisor_msg="Supervisor: Task seems complete."
    return {
        "messages":[AIMessage(content=supervisor_msg)],
        "next_agent":next_agent,
        "current_task":task
    }

# %%
def researcher_agent(state:SuperVisorState)->dict:
    """researcher uses Groq to gather information"""
    task=state.get("current_task","research topic")
    #create research prompt
    research_prompt=f"""Aa a researcher specialist,provide comprehensive information about:{task}
    
    Include:
    1. Key facts and background
    2. Current trends or developments
    3. Important statistics or data points
    4. Notable examples or case studies
    Be concise but thorough  
    """
    #Get report from LLM
    research_response=llm.invoke([HumanMessage(content=research_prompt)])
    research_data=research_response.content
    #create agent message
    agent_message=f"Researche: I have completed the research on '{task}'.\n\nKey findings:\n{research_data}"
    return{
        "messages":[AIMessage(content=agent_message)],
        "research_data":research_data,
        "next_agent":"supervisor",
         
     }

# %%
def analyst_agent(state:SuperVisorState)->dict:
    """Analyst uses Groq to analyze the data"""
    research_data=state.get("research_data","")
    task=state.get("current_task","")
    #create research prompt
    analysis_prompt=f"""As a data analyst. analyze this research data and provide insights:
Research data:
{research_data}
Provide:
1.Key insights and patterns
2.Strategic implications
3.Risk and opportunities
4.Recommendations
Focus in actionable insights related to:{task}  
    """
    #Get report from LLM
    analysis_response=llm.invoke([HumanMessage(content=analysis_prompt)])
    analysis=analysis_response.content
    #create agent message
    agent_message=f"Analyst: I have completed the analysis.\n\nTop Insights:\n{analysis}"
    return{ 
        "messages":[AIMessage(content=agent_message)],
        "analysis":analysis,
        "next_agent":"supervisor",
         
     }

# %%
def writer_agent(state:SuperVisorState)->dict:
    """Writer uses Groq to create final report"""
    research_data = state.get("research_data","")
    analysis=state.get("analysis","")
    task=state.get("current_task","")
    #create writing prompt
    writer_prompt=f"""Aa a professional writer,create an executive report based on:
    
Task:{task}

Research_findings:
{research_data[:1000]}
Analysis:
{analysis[:1000]}
Create a well-structured report with:
1.Executive summary
2.key Findings
3.Analysis & Insights
4.Recommendations
5.Conclusions
Keep it professional and concise    
    """
    #Get report from LLM
    report_response=llm.invoke([HumanMessage(content=writer_prompt)])
    report=report_response.content
    #create final formatted report
    final_report=f"""
    Final Report
{'='*50}
Generated:{datetime.now().strftime('%Y-%m-%d %H:%M')}
Topic:{task}
{'='*50}
{report}
{'='*50}
Report compiled by Multi-Agent aisystem powered by Groq
""" 
    return{
        "messages":[AIMessage(content=f"writer:report complete! see below for the full document")],
        "final_report":final_report,
        "next_agent":"supervisor",
        "task_complete":True       
     }

# %%
def router(state:SuperVisorState)-> Literal["supervisor","researcher","analyst","writer","__end__"]:
    """Routes to next agent  based on state"""
    next_agent=state.get("next_agent","supervisor")
    if next_agent == "end" or state.get("task_complete",False):
        return END
    if next_agent in ["supervisor","researcher","analyst","writer"]:
        return next_agent
    return "supervisor"

# %%
workflow=StateGraph(SuperVisorState)
workflow.add_node("supervisor",supervisor_agent)
workflow.add_node("researcher",researcher_agent)
workflow.add_node("analyst",analyst_agent)
workflow.add_node("writer",writer_agent)
workflow.set_entry_point('supervisor')

for node in ["supervisor","researcher","analyst","writer"]:
    workflow.add_conditional_edges(
        node,
        router,
        {
            "supervisor":"supervisor",
            "researcher":"researcher",
            "analyst":"analyst",
            "writer":"writer",
            END:END
        })
graph=workflow.compile()
    
graph

# %%
graph.invoke(HumanMessage(content="what are major development in the recent research related to ai"))
# Out:
# researcher
# researcher
# researcher
# researcher
# analyser
# writer: the analyst has completed the analysis. now it's time for the writer to create a report based on the insights and recommendations.
# writer
# {'messages': [AIMessage(content="Supervisor: let's start with research. Assigning to researcher...", additional_kwargs={}, response_metadata={}, id='69a6dfee-cdfe-491e-9fc6-0b9ef3f96fe1'),
#   AIMessage(content="Researche: I have completed the research on 'no task'.\n\nKey findings:\nIt seems you didn't provide a task. Please provide a task or topic you would like me to research and provide comprehensive information about. \n\nOnce I have the topic, I can provide you with the following:\n\n1. Key facts and background\n2. Current trends or developments\n3. Important statistics or data points\n4. Notable examples or case studies\n\nI'll be happy to assist you with your request.", additional_kwargs={}, response_metadata={}, id='43079e27-7e70-4075-b636-3e68476a7151'),
#   AIMessage(content="Supervisor: let's start with research. Assigning to researcher...", additional_kwargs={}, response_metadata={}, id='37dba90e-3fa5-4a72-be06-83894e112c08'),
#   AIMessage(content="Researche: I have completed the research on 'Researche: I have completed the research on 'no task'.\n\nKey findings:\nIt seems you didn't provide a task. Please provide a task or topic you would like me to research and provide comprehensive information about. \n\nOnce I have the topic, I can provide you with the following:\n\n1. Key facts and background\n2. Current trends or developments\n3. Important statistics or data points\n4. Notable examples or case studies\n\nI'll be happy to assist you with your request.'.\n\nKey findings:\nI'm glad to provide a task for you to conduct research on. Here's a topic:\n\n**Topic: Sustainable Energy Transition in Developing Countries**\n\nAs a researcher, please provide comprehensive information about the sustainable energy transition in developing countries. This topic is crucial for understanding the shift towards renewable energy sources, reducing dependence on fossil fuels, and mitigating climate change.\n\n**Please provide the following information:**\n\n1. **Key facts and background**: Briefly describe the current energy landscape in developing countries, including the reliance on fossil fuels, energy poverty, and the potential of renewable energy sources.\n2. **Current trends or developments**: Discuss the latest trends and developments in the sustainable energy transition, including the adoption of solar, wind, and hydroelectric power, energy storage technologies, and grid modernization.\n3. **Important statistics or data points**: Provide statistics on the growth of renewable energy capacity, energy access rates, and greenhouse gas emissions reductions in developing countries.\n4. **Notable examples or case studies**: Highlight successful examples of sustainable energy transitions in developing countries, such as Costa Rica's renewable energy ambitions, Rwanda's solar-powered irrigation systems, or India's solar-powered villages.\n\nI'm looking forward to your comprehensive research report on this topic.", additional_kwargs={}, response_metadata={}, id='95e570a2-f628-4346-84bc-e3539caada5f'),
#   AIMessage(content="Supervisor: let's start with research. Assigning to researcher...", additional_kwargs={}, response_metadata={}, id='b4323a8d-f2a7-4e49-ae29-df050d1fbc11'),
#   AIMessage(content="Researche: I have completed the research on 'Researche: I have completed the research on 'Researche: I have completed the research on 'no task'.\n\nKey findings:\nIt seems you didn't provide a task. Please provide a task or topic you would like me to research and provide comprehensive information about. \n\nOnce I have the topic, I can provide you with the following:\n\n1. Key facts and background\n2. Current trends or developments\n3. Important statistics or data points\n4. Notable examples or case studies\n\nI'll be happy to assist you with your request.'.\n\nKey findings:\nI'm glad to provide a task for you to conduct research on. Here's a topic:\n\n**Topic: Sustainable Energy Transition in Developing Countries**\n\nAs a researcher, please provide comprehensive information about the sustainable energy transition in developing countries. This topic is crucial for understanding the shift towards renewable energy sources, reducing dependence on fossil fuels, and mitigating climate change.\n\n**Please provide the following information:**\n\n1. **Key facts and background**: Briefly describe the current energy landscape in developing countries, including the reliance on fossil fuels, energy poverty, and the potential of renewable energy sources.\n2. **Current trends or developments**: Discuss the latest trends and developments in the sustainable energy transition, including the adoption of solar, wind, and hydroelectric power, energy storage technologies, and grid modernization.\n3. **Important statistics or data points**: Provide statistics on the growth of renewable energy capacity, energy access rates, and greenhouse gas emissions reductions in developing countries.\n4. **Notable examples or case studies**: Highlight successful examples of sustainable energy transitions in developing countries, such as Costa Rica's renewable energy ambitions, Rwanda's solar-powered irrigation systems, or India's solar-powered villages.\n\nI'm looking forward to your comprehensive research report on this topic.'.\n\nKey findings:\n**Comprehensive Research Report: Sustainable Energy Transition in Developing Countries**\n\n**1. Key Facts and Background**\n\n* **Energy Landscape in Developing Countries**: Developing countries account for 80% of the world's population and 70% of the global energy demand. However, most of these countries rely heavily on fossil fuels for energy generation, leading to significant greenhouse gas emissions and energy poverty.\n* **Energy Poverty**: Over 1 billion people in developing countries lack access to electricity, and 2.6 billion rely on traditional biomass, such as charcoal and wood, for cooking and heating.\n* **Renewable Energy Potential**: Developing countries have vast renewable energy resources, including solar, wind, hydro, and geothermal energy. Solar radiation, in particular, is abundant in many developing countries, making it an attractive option for electricity generation.\n* **Energy Access Rates**: According to the International Energy Agency (IEA), energy access rates in developing countries are improving, with 90% of the population having access to electricity in 2020, up from 70% in 2010.\n\n**2. Current Trends or Developments**\n\n* **Adoption of Renewable Energy Sources**: Developing countries are rapidly adopting renewable energy sources, with solar and wind power being the most popular options. In 2020, developing countries accounted for 45% of global solar PV installations and 30% of global wind power installations.\n* **Energy Storage Technologies**: The development of energy storage technologies, such as batteries and pumped hydro storage, is crucial for integrating intermittent renewable energy sources into the grid and ensuring a stable energy supply.\n* **Grid Modernization**: Developing countries are investing in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and r ...
#   AIMessage(content="Supervisor: let's start with research. Assigning to researcher...", additional_kwargs={}, response_metadata={}, id='dbb691c9-48a9-4a66-844a-42db0973cdd5'),
#   AIMessage(content="Researche: I have completed the research on 'Researche: I have completed the research on 'Researche: I have completed the research on 'Researche: I have completed the research on 'no task'.\n\nKey findings:\nIt seems you didn't provide a task. Please provide a task or topic you would like me to research and provide comprehensive information about. \n\nOnce I have the topic, I can provide you with the following:\n\n1. Key facts and background\n2. Current trends or developments\n3. Important statistics or data points\n4. Notable examples or case studies\n\nI'll be happy to assist you with your request.'.\n\nKey findings:\nI'm glad to provide a task for you to conduct research on. Here's a topic:\n\n**Topic: Sustainable Energy Transition in Developing Countries**\n\nAs a researcher, please provide comprehensive information about the sustainable energy transition in developing countries. This topic is crucial for understanding the shift towards renewable energy sources, reducing dependence on fossil fuels, and mitigating climate change.\n\n**Please provide the following information:**\n\n1. **Key facts and background**: Briefly describe the current energy landscape in developing countries, including the reliance on fossil fuels, energy poverty, and the potential of renewable energy sources.\n2. **Current trends or developments**: Discuss the latest trends and developments in the sustainable energy transition, including the adoption of solar, wind, and hydroelectric power, energy storage technologies, and grid modernization.\n3. **Important statistics or data points**: Provide statistics on the growth of renewable energy capacity, energy access rates, and greenhouse gas emissions reductions in developing countries.\n4. **Notable examples or case studies**: Highlight successful examples of sustainable energy transitions in developing countries, such as Costa Rica's renewable energy ambitions, Rwanda's solar-powered irrigation systems, or India's solar-powered villages.\n\nI'm looking forward to your comprehensive research report on this topic.'.\n\nKey findings:\n**Comprehensive Research Report: Sustainable Energy Transition in Developing Countries**\n\n**1. Key Facts and Background**\n\n* **Energy Landscape in Developing Countries**: Developing countries account for 80% of the world's population and 70% of the global energy demand. However, most of these countries rely heavily on fossil fuels for energy generation, leading to significant greenhouse gas emissions and energy poverty.\n* **Energy Poverty**: Over 1 billion people in developing countries lack access to electricity, and 2.6 billion rely on traditional biomass, such as charcoal and wood, for cooking and heating.\n* **Renewable Energy Potential**: Developing countries have vast renewable energy resources, including solar, wind, hydro, and geothermal energy. Solar radiation, in particular, is abundant in many developing countries, making it an attractive option for electricity generation.\n* **Energy Access Rates**: According to the International Energy Agency (IEA), energy access rates in developing countries are improving, with 90% of the population having access to electricity in 2020, up from 70% in 2010.\n\n**2. Current Trends or Developments**\n\n* **Adoption of Renewable Energy Sources**: Developing countries are rapidly adopting renewable energy sources, with solar and wind power being the most popular options. In 2020, developing countries accounted for 45% of global solar PV installations and 30% of global wind power installations.\n* **Energy Storage Technologies**: The development of energy storage technologies, such as batteries and pumped hydro storage, is crucial for integrating intermittent renewable energy sources into the grid and ensuring a stable energy supply.\n* **Grid Modernization**: Developing countries are investing in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid managemen ...
#   AIMessage(content='Supervisor: research done. Time for analysis. Assigning to analyst...', additional_kwargs={}, response_metadata={}, id='43bbc370-16f6-43f9-bad0-0706742a3065'),
#   AIMessage(content='Analyst: I have completed the analysis.\n\nTop Insights:\n**Key Insights and Patterns**\n\n1. **Growing demand for renewable energy**: Developing countries are rapidly adopting renewable energy sources, with solar and wind power being the most popular options.\n2. **Improving energy access rates**: Energy access rates in developing countries are improving, with 90% of the population having access to electricity in 2020, up from 70% in 2010.\n3. **Reducing greenhouse gas emissions**: Developing countries have made significant progress in reducing greenhouse gas emissions, with a 25% reduction in emissions per unit of GDP between 2010 and 2020.\n4. **Increased investment in renewable energy**: Developing countries have attracted significant investment in renewable energy, with $150 billion invested in solar and wind energy projects in 2020 alone.\n\n**Strategic Implications**\n\n1. **Diversifying energy sources**: Developing countries should continue to invest in renewable energy sources to reduce dependence on fossil fuels and mitigate climate change.\n2. **Improving energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhancing energy access**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promoting sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Risk and Opportunities**\n\n1. **Energy security risks**: Developing countries may face energy security risks due to dependence on fossil fuels and potential disruptions in energy supply.\n2. **Climate change risks**: Developing countries are vulnerable to climate change impacts, including extreme weather events, sea-level rise, and water scarcity.\n3. **Opportunities for economic growth**: Renewable energy investments can create jobs, stimulate economic growth, and improve energy access in developing countries.\n4. **Opportunities for energy independence**: Developing countries can reduce dependence on fossil fuels and improve energy security by investing in renewable energy sources.\n\n**Recommendations**\n\n1. **Develop and implement renewable energy policies**: Developing countries should develop and implement policies to support the development and deployment of renewable energy sources.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promote sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Actionable Insights**\n\n1. **Developing countries should prioritize renewable energy investments**: Developing countries should prioritize investments in renewable energy sources, such as solar and wind power, to reduce dependence on fossil fuels and mitigate climate change.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promote sustainable energy financing**: In ...
#   AIMessage(content='Supervisor: research done. Time for analysis. Assigning to analyst...', additional_kwargs={}, response_metadata={}, id='9edf1fe2-3b22-4cc4-80c2-3e312f4f8e54'),
#   AIMessage(content='Analyst: I have completed the analysis.\n\nTop Insights:\n**Key Insights and Patterns**\n\n1. **Growing demand for renewable energy**: Developing countries are rapidly adopting renewable energy sources, with solar and wind power being the most popular options.\n2. **Improving energy access rates**: Energy access rates in developing countries are improving, with 90% of the population having access to electricity in 2020, up from 70% in 2010.\n3. **Reducing greenhouse gas emissions**: Developing countries have made significant progress in reducing greenhouse gas emissions, with a 25% reduction in emissions per unit of GDP between 2010 and 2020.\n4. **Increased investment in renewable energy**: Developing countries have attracted significant investment in renewable energy, with $150 billion invested in solar and wind energy projects in 2020 alone.\n\n**Strategic Implications**\n\n1. **Diversifying energy sources**: Developing countries should continue to invest in renewable energy sources to reduce dependence on fossil fuels and mitigate climate change.\n2. **Improving energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhancing energy access**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promoting sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Risk and Opportunities**\n\n1. **Energy security risks**: Developing countries may face energy security risks due to dependence on fossil fuels and potential disruptions in energy supply.\n2. **Climate change risks**: Developing countries are vulnerable to climate change impacts, including extreme weather events, sea-level rise, and water scarcity.\n3. **Opportunities for economic growth**: Renewable energy investments can create jobs, stimulate economic growth, and improve energy access in developing countries.\n4. **Opportunities for energy independence**: Developing countries can reduce dependence on fossil fuels and improve energy security by investing in renewable energy sources.\n\n**Recommendations**\n\n1. **Develop and implement renewable energy policies**: Developing countries should develop and implement policies to support the development and deployment of renewable energy sources.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promote sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Actionable Insights**\n\n1. **Developing countries should prioritize renewable energy investments**: Developing countries should prioritize investments in renewable energy sources, such as solar and wind power, to reduce dependence on fossil fuels and mitigate climate change.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promote sustainable energy financing**: In ...
#   AIMessage(content="Supervisor: Analysis complete. Let's create the report. Assigning to Writer...", additional_kwargs={}, response_metadata={}, id='8d629efa-0a6a-445e-a24c-2a73c7fbf469'),
#   AIMessage(content='writer:report complete! see below for the full document', additional_kwargs={}, response_metadata={}, id='a8daf091-7e99-427e-9c14-2ccc05115704')],
#  'next_agent': 'supervisor',
#  'research_data': "**Comprehensive Research Report: Sustainable Energy Transition in Developing Countries**\n\n**1. Key Facts and Background**\n\n* **Energy Landscape in Developing Countries**: Developing countries account for 80% of the world's population and 70% of the global energy demand, with most relying heavily on fossil fuels for energy generation, leading to significant greenhouse gas emissions and energy poverty.\n* **Energy Poverty**: Over 1 billion people in developing countries lack access to electricity, and 2.6 billion rely on traditional biomass, such as charcoal and wood, for cooking and heating.\n* **Renewable Energy Potential**: Developing countries have vast renewable energy resources, including solar, wind, hydro, and geothermal energy, with solar radiation being abundant in many countries.\n* **Energy Access Rates**: Energy access rates in developing countries are improving, with 90% of the population having access to electricity in 2020, up from 70% in 2010.\n\n**2. Current Trends or Developments**\n\n* **Adoption of Renewable Energy Sources**: Developing countries are rapidly adopting renewable energy sources, with solar and wind power being the most popular options, accounting for 45% and 30% of global installations, respectively.\n* **Energy Storage Technologies**: The development of energy storage technologies, such as batteries and pumped hydro storage, is crucial for integrating intermittent renewable energy sources into the grid and ensuring a stable energy supply.\n* **Grid Modernization**: Developing countries are investing in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n* **Financing and Investment**: International financial institutions, such as the World Bank and the Asian Infrastructure Investment Bank (AIIB), are providing financing and investment opportunities for sustainable energy projects in developing countries.\n\n**3. Important Statistics or Data Points**\n\n* **Renewable Energy Capacity Growth**: Global renewable energy capacity has grown from 1,200 gigawatts (GW) in 2010 to over 2,400 GW in 2020, with developing countries accounting for 45% of this growth.\n* **Energy Access Rates**: Energy access rates in developing countries are improving, with 90% of the population having access to electricity in 2020, up from 70% in 2010.\n* **Greenhouse Gas Emissions Reductions**: Developing countries have made significant progress in reducing greenhouse gas emissions, with a 25% reduction in emissions per unit of GDP between 2010 and 2020.\n* **Investment in Renewable Energy**: Developing countries have attracted significant investment in renewable energy, with $150 billion invested in solar and wind energy projects in 2020 alone.\n\n**4. Notable Examples or Case Studies**\n\n* **Costa Rica's Renewable Energy Ambitions**: Costa Rica aims to power 100% of its electricity from renewable sources by 2050, with a focus on hydroelectric and geothermal energy.\n* **Rwanda's Solar-Powered Irrigation Systems**: Rwanda has implemented a solar-powered irrigation system, providing clean energy and water for over 10,000 farmers and improving crop yields by 20%.\n* **India's Solar-Powered Villages**: India has implemented a solar-powered village program, providing electricity to over 100 villages and reducing energy poverty by 50%.\n* **Kenya's Geothermal Energy**: Kenya has harnessed its geothermal resources to generate 10% of its electricity, providing clean energy and reducing greenhouse gas emissions.\n\n**Conclusion**: The sustainable energy transition in developing countries is gaining momentum, with significant progress made in adopting renewable energy sources, improving energy access rates, and reducing greenhouse gas emissions. Notable examples and case studies demonstrate the potential of sustainable energy solutions in developing countries, and it is essential to c ...
#  'analysis': '**Key Insights and Patterns**\n\n1. **Growing demand for renewable energy**: Developing countries are rapidly adopting renewable energy sources, with solar and wind power being the most popular options.\n2. **Improving energy access rates**: Energy access rates in developing countries are improving, with 90% of the population having access to electricity in 2020, up from 70% in 2010.\n3. **Reducing greenhouse gas emissions**: Developing countries have made significant progress in reducing greenhouse gas emissions, with a 25% reduction in emissions per unit of GDP between 2010 and 2020.\n4. **Increased investment in renewable energy**: Developing countries have attracted significant investment in renewable energy, with $150 billion invested in solar and wind energy projects in 2020 alone.\n\n**Strategic Implications**\n\n1. **Diversifying energy sources**: Developing countries should continue to invest in renewable energy sources to reduce dependence on fossil fuels and mitigate climate change.\n2. **Improving energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhancing energy access**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promoting sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Risk and Opportunities**\n\n1. **Energy security risks**: Developing countries may face energy security risks due to dependence on fossil fuels and potential disruptions in energy supply.\n2. **Climate change risks**: Developing countries are vulnerable to climate change impacts, including extreme weather events, sea-level rise, and water scarcity.\n3. **Opportunities for economic growth**: Renewable energy investments can create jobs, stimulate economic growth, and improve energy access in developing countries.\n4. **Opportunities for energy independence**: Developing countries can reduce dependence on fossil fuels and improve energy security by investing in renewable energy sources.\n\n**Recommendations**\n\n1. **Develop and implement renewable energy policies**: Developing countries should develop and implement policies to support the development and deployment of renewable energy sources.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promote sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Actionable Insights**\n\n1. **Developing countries should prioritize renewable energy investments**: Developing countries should prioritize investments in renewable energy sources, such as solar and wind power, to reduce dependence on fossil fuels and mitigate climate change.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promote sustainable energy financing**: International financial institutions and governments should provide ...
#  'final_report': '\n    Final Report\n==================================================\nGenerated:2025-10-21 23:56\nTopic:Analyst: I have completed the analysis.\n\nTop Insights:\n**Key Insights and Patterns**\n\n1. **Growing demand for renewable energy**: Developing countries are rapidly adopting renewable energy sources, with solar and wind power being the most popular options.\n2. **Improving energy access rates**: Energy access rates in developing countries are improving, with 90% of the population having access to electricity in 2020, up from 70% in 2010.\n3. **Reducing greenhouse gas emissions**: Developing countries have made significant progress in reducing greenhouse gas emissions, with a 25% reduction in emissions per unit of GDP between 2010 and 2020.\n4. **Increased investment in renewable energy**: Developing countries have attracted significant investment in renewable energy, with $150 billion invested in solar and wind energy projects in 2020 alone.\n\n**Strategic Implications**\n\n1. **Diversifying energy sources**: Developing countries should continue to invest in renewable energy sources to reduce dependence on fossil fuels and mitigate climate change.\n2. **Improving energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhancing energy access**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promoting sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Risk and Opportunities**\n\n1. **Energy security risks**: Developing countries may face energy security risks due to dependence on fossil fuels and potential disruptions in energy supply.\n2. **Climate change risks**: Developing countries are vulnerable to climate change impacts, including extreme weather events, sea-level rise, and water scarcity.\n3. **Opportunities for economic growth**: Renewable energy investments can create jobs, stimulate economic growth, and improve energy access in developing countries.\n4. **Opportunities for energy independence**: Developing countries can reduce dependence on fossil fuels and improve energy security by investing in renewable energy sources.\n\n**Recommendations**\n\n1. **Develop and implement renewable energy policies**: Developing countries should develop and implement policies to support the development and deployment of renewable energy sources.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promote sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Actionable Insights**\n\n1. **Developing countries should prioritize renewable energy investments**: Developing countries should prioritize investments in renewable energy sources, such as solar and wind power, to reduce dependence on fossil fuels and mitigate climate change.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all c ...
#  'task_complete': True,
#  'current_task': 'Analyst: I have completed the analysis.\n\nTop Insights:\n**Key Insights and Patterns**\n\n1. **Growing demand for renewable energy**: Developing countries are rapidly adopting renewable energy sources, with solar and wind power being the most popular options.\n2. **Improving energy access rates**: Energy access rates in developing countries are improving, with 90% of the population having access to electricity in 2020, up from 70% in 2010.\n3. **Reducing greenhouse gas emissions**: Developing countries have made significant progress in reducing greenhouse gas emissions, with a 25% reduction in emissions per unit of GDP between 2010 and 2020.\n4. **Increased investment in renewable energy**: Developing countries have attracted significant investment in renewable energy, with $150 billion invested in solar and wind energy projects in 2020 alone.\n\n**Strategic Implications**\n\n1. **Diversifying energy sources**: Developing countries should continue to invest in renewable energy sources to reduce dependence on fossil fuels and mitigate climate change.\n2. **Improving energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhancing energy access**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promoting sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Risk and Opportunities**\n\n1. **Energy security risks**: Developing countries may face energy security risks due to dependence on fossil fuels and potential disruptions in energy supply.\n2. **Climate change risks**: Developing countries are vulnerable to climate change impacts, including extreme weather events, sea-level rise, and water scarcity.\n3. **Opportunities for economic growth**: Renewable energy investments can create jobs, stimulate economic growth, and improve energy access in developing countries.\n4. **Opportunities for energy independence**: Developing countries can reduce dependence on fossil fuels and improve energy security by investing in renewable energy sources.\n\n**Recommendations**\n\n1. **Develop and implement renewable energy policies**: Developing countries should develop and implement policies to support the development and deployment of renewable energy sources.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promote sustainable energy financing**: International financial institutions and governments should provide financing and investment opportunities for sustainable energy projects in developing countries.\n\n**Actionable Insights**\n\n1. **Developing countries should prioritize renewable energy investments**: Developing countries should prioritize investments in renewable energy sources, such as solar and wind power, to reduce dependence on fossil fuels and mitigate climate change.\n2. **Invest in energy infrastructure**: Developing countries should invest in grid modernization efforts, including the deployment of smart grids, distribution networks, and grid management systems, to improve energy efficiency and reduce energy losses.\n3. **Enhance energy access initiatives**: Developing countries should prioritize energy access initiatives to ensure that all citizens have access to affordable and reliable energy.\n4. **Promote sustainable energy financing**: Inter ...
